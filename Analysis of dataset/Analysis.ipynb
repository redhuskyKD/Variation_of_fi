# %%
import pandas as pd
import seaborn as sns

# %%
df=pd.read_excel('values.xls')

# %%
df.describe()
# Out:
#               eta         m=0         m=1       m=1.5         m=2       m=2.5
# count  381.000000  381.000000  381.000000  381.000000  381.000000  381.000000
# mean     1.050000    0.521319    1.893157    2.551156    3.179192    3.789264
# std      0.550647    0.317324    1.631192    2.289396    2.921732    3.537590
# min      0.100000    0.019079    0.021390    0.022149    0.022818    0.023449
# 25%      0.575000    0.238683    0.445327    0.530331    0.609460    0.685616
# 50%      1.050000    0.510201    1.431274    1.847734    2.241565    2.622740
# 75%      1.525000    0.795206    3.106750    4.217147    5.277197    6.306957
# max      2.000000    1.085767    5.598513    7.862289   10.037325   12.155598

# %%
df.head()
# Out:
#      eta       m=0       m=1     m=1.5       m=2     m=2.5
# 0  0.100  0.019079  0.021390  0.022149  0.022818  0.023449
# 1  0.105  0.020581  0.023208  0.024075  0.024841  0.025563
# 2  0.110  0.022118  0.025086  0.026070  0.026941  0.027764
# 3  0.115  0.023690  0.027024  0.028135  0.029120  0.030051
# 4  0.120  0.025294  0.029022  0.030270  0.031378  0.032425

# %%
df.tail()
# Out:
#        eta       m=0       m=1     m=1.5        m=2      m=2.5
# 376  1.980  1.073464  5.475544  7.680316   9.798179  11.860583
# 377  1.985  1.076539  5.506131  7.725564   9.857631  11.933915
# 378  1.990  1.079615  5.536822  7.770975   9.917306  12.007528
# 379  1.995  1.082691  5.567616  7.816550   9.977204  12.081422
# 380  2.000  1.085767  5.598513  7.862289  10.037325  12.155598

# %%
ndf=df.melt('eta', var_name='hue',value_name='fi')

# %%
ndf.head()
# Out:
#      eta  hue        fi
# 0  0.100  m=0  0.019079
# 1  0.105  m=0  0.020581
# 2  0.110  m=0  0.022118
# 3  0.115  m=0  0.023690
# 4  0.120  m=0  0.025294

# %%
ndf.tail()
# Out:
#         eta    hue         fi
# 1900  1.980  m=2.5  11.860583
# 1901  1.985  m=2.5  11.933915
# 1902  1.990  m=2.5  12.007528
# 1903  1.995  m=2.5  12.081422
# 1904  2.000  m=2.5  12.155598

# %%
sns.scatterplot(data=ndf,x='eta',hue='hue',y='fi')
# Out:
# <Axes: xlabel='eta', ylabel='fi'>
